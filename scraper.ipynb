# %%
import codecs
import pandas
import re
def mid(s, offset, amount):
    return s[offset-1:offset+amount-1]
filepath = 'C:\\Users\\hp\\Dropbox\\etudes en france\\EPITA\\PRI\\KEA Medicals\\documentation\\cmd1.txt'  
with codecs.open(filepath,  "r", "utf-8") as fp:  
   line = fp.readline()
   cnt = 1
   while line:
        str = line.strip()
        m = re.match("(^[A-Z]\d[0-9])", str)
        if m:
            print(str) 
        line = fp.readline()
# Out:
# A06.6
# A17.0
# A17.1
# A17.8
# A17.9
# A20.3
# A32.1
# A39.0
# A50.4
# A52.1
# A52.2
# A52.3
# A80.0
# A80.1
# A80.2
# A80.3
# A80.9
# A81.0
# A81.1
# A81.2
# A81.8
# A81.9
# A82.0
# A82.1
# A82.9
# A83.0
# A83.1
# A83.2
# A83.3
# A83.4
# A83.5
# A83.6
# A83.8
# A83.9
# A84.0
# A84.1
# A84.8
# A84.9
# A85.0
# A85.1
# A85.2
# A85.8
# A86
# A87.0
# A87.1
# A87.2
# A87.8
# A87.9
# A88.0
# A88.8
# A89
# A92.2
# B00.3
# B00.4
# B01.0
# B01.1
# B02.0
# B02.1
# B02.2
# B05.0
# B05.1
# B06.0
# B26.1
# B26.2
# B37.5
# B38.4
# B43.1
# B45.1
# B50.0
# B57.4
# B58.2
# B60.2
# B69.0
# B83.2
# C47.0
# C47.1
# C47.2
# C47.3
# C47.4
# C47.5
# C47.6
# C47.8
# C47.9
# C70.0
# C70.1
# C70.9
# C71.0
# C71.1
# C71.2
# C71.3
# C71.4
# C71.5
# C71.6
# C71.7
# C71.8
# C71.9
# C72.0
# C72.1
# C72.2
# C72.3
# C72.4
# C72.5
# C72.8
# C72.9
# C75.3
# C75.4
# C75.5
# C79.3
# C79.4
# D32.0
# D32.1
# D32.9
# D33.0
# D33.1
# D33.2
# D33.3
# D33.4
# D33.7
# D33.9
# D35.4
# D35.5
# D35.6
# D36.1
# D42.0
# D42.1
# ...

# %%
mid("Liste D-326",7,5)
# Out:
# 'D-326'
